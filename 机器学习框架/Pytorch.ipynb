# %% [markdown]
# # Pytorch框架
# - Pytorch官方文档：https://docs.pytorch.org/docs/stable/index.html
# - Pytorch中文版官网：https://pytorch.ac.cn/
#
# Pytorch是来自于Meta的一个深度学习框架，在目前深度学习的模型训练中经常使用，算是最流行也是最基础的框架，类似的框架还有亚马逊的MXnet，和Google的Tensorflow。PyTorch 还针对 CPU、GPU 和自定义硬件加速器进行了性能优化，所以也可以用来做分布式计算。

# %% [markdown]
# # 1.Pytorch的安装与使用
# 安装过程可参考 https://pytorch.ac.cn/get-started/locally/ 页面。
#
# 建议想要快速开始的同学，可以从google colab（https://colab.research.google.com/）
# 中使用，colab提供免费的T4 GPU，并且预装了很多跟机器学习，深度学习有关的库，并且也可以连接到Github上进行远程开发，而无需在本地环境预装库包。从26年初起，Colab已经可以直接在vscode上无痛使用了

# %%
#创建一个张量Tensor
import torch
x = torch.rand(5, 3)
print(x)
# Out:
# tensor([[0.7986, 0.8652, 0.5444],
#         [0.0677, 0.7541, 0.1740],
#         [0.5174, 0.8171, 0.1450],
#         [0.7910, 0.5839, 0.3751],
#         [0.5371, 0.8829, 0.8025]])

# %%
#检测是否有GPU可用
cuda_available = torch.cuda.is_available()
print(f"CUDA Available: {cuda_available}")
# Out:
# CUDA Available: True

# %%
torch.tensor([1,2])
